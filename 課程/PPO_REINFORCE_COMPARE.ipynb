# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/python-tutoring-materials/blob/main/%E8%AA%B2%E7%A8%8B/PPO_REINFORCE_COMPARE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
env_name = 'CartPole-v0'
max_episodes = 3000
print_interval = 100
roll_mean = 30

# %% [markdown]
# # Reinforce

# %%
url = 'https://gist.githubusercontent.com/skywalker0803r/e3670ecbdc13ea04fb33d3035b5b9147/raw/c617f22c94bf1e3ef9115509e12fefba7a83725b/reinforce.py'
exec(requests.get(url).text)
env = gym.make(env_name)
history_reinforce = reinforce(env,n_episodes=max_episodes,print_every=print_interval)
plt.plot(history_reinforce)
plt.plot(pd.Series(history_reinforce).rolling(roll_mean).mean())
# Out:
# Episode 100	Average Score: 29.90
# Episode 200	Average Score: 58.35
# Episode 300	Average Score: 57.47
# Episode 400	Average Score: 154.86
# Episode 500	Average Score: 159.58
# Episode 600	Average Score: 144.80
# Episode 700	Average Score: 140.82
# Episode 800	Average Score: 64.47
# Episode 900	Average Score: 97.06
# Episode 1000	Average Score: 73.33
# Episode 1100	Average Score: 61.42
# Episode 1200	Average Score: 55.04
# Episode 1300	Average Score: 69.27
# Episode 1400	Average Score: 125.20
# Episode 1500	Average Score: 113.64
# Episode 1600	Average Score: 96.13
# Episode 1700	Average Score: 76.28
# Episode 1800	Average Score: 88.73
# Episode 1900	Average Score: 80.10
# Episode 2000	Average Score: 124.30
# Episode 2100	Average Score: 96.29
# Episode 2200	Average Score: 94.97
# Episode 2300	Average Score: 84.37
# Episode 2400	Average Score: 93.20
# Episode 2500	Average Score: 168.61
# Episode 2600	Average Score: 148.52
# Episode 2700	Average Score: 90.25
# Episode 2800	Average Score: 63.94
# Episode 2900	Average Score: 50.72
# Episode 3000	Average Score: 41.19

# %% [markdown]
# # PPO

# %%
url = 'https://gist.githubusercontent.com/skywalker0803r/c363d8b2cf72a8aee06bc238a355fa01/raw/950f12a95eaab432a76dcf070fc40630b555a254/PPO.py'
exec(requests.get(url).text)
env = gym.make(env_name)
agent = PPOAgent(env)
history_ppo = agent.train(max_episodes=max_episodes,print_interval=print_interval)
plt.plot(history_ppo)
plt.plot(pd.Series(history_ppo).rolling(roll_mean).mean())
# Out:
# Episode 0: 14.0
# Episode 100: 200.0
# Episode 200: 200.0
# Episode 300: 200.0
# Episode 400: 200.0
# Episode 500: 200.0
# Episode 600: 200.0
# Episode 700: 153.0
# Episode 800: 200.0
# Episode 900: 181.0
# Episode 1000: 177.0
# Episode 1100: 200.0
# Episode 1200: 200.0
# Episode 1300: 200.0
# Episode 1400: 200.0
# Episode 1500: 200.0
# Episode 1600: 17.0
# Episode 1700: 200.0
# Episode 1800: 200.0
# Episode 1900: 200.0
# Episode 2000: 200.0
# Episode 2100: 200.0
# Episode 2200: 200.0
# Episode 2300: 200.0
# Episode 2400: 200.0
# Episode 2500: 200.0
# Episode 2600: 200.0
# Episode 2700: 200.0
# Episode 2800: 200.0
# Episode 2900: 200.0

# %%
plt.plot(pd.Series(history_reinforce).rolling(15).mean(),label='reinforce')
plt.plot(pd.Series(history_ppo).rolling(15).mean(),label='ppo')
plt.legend()
plt.show()
