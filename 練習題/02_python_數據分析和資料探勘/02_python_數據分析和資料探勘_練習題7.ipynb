# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/python-tutoring-materials/blob/main/02_python_%E6%95%B8%E6%93%9A%E5%88%86%E6%9E%90%E5%92%8C%E8%B3%87%E6%96%99%E6%8E%A2%E5%8B%98_%E7%B7%B4%E7%BF%92%E9%A1%8C7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA

# 读取数据
data = pd.read_csv('Iris.csv',index_col=0)
print(data['Species'].value_counts())
data = data.drop('Species',axis=1)
display(data)

# 对数据进行主成分分析（PCA），将数据降至二维
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data)

# 使用 DBSCAN 聚类算法
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(data_pca)

# 将聚类结果可视化
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=clusters)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('DBSCAN Clustering of Iris Data')
plt.show()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]
